# %% [markdown]
# # VGG-13 transformed to SNN and tested with cifar-10
#
# This will be a tutorial of how to transform the VGG-13 model to an snn model using ml-genn. First, we need to import all the libraries that will be used.

# %%
import tensorflow as tf
import ml_genn as tg
from ml_genn import Model
from ml_genn.utils import raster_plot
import numpy as np
from six import iteritems
from time import perf_counter
import argparse
from ml_genn.layers import ConnectivityType
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
import os
from ml_genn.converters import Simple
from ml_genn.converters import DataNorm
from ml_genn.converters import SpikeNorm
from ml_genn.converters import FewSpike
tf.random.set_seed(2345)
np.random.seed(2345)


#config = tf.ConfigProto()
#config.gpu_options.allow_growth=True
#sess = tf.Session(config=config)

for gpu in tf.config.experimental.list_physical_devices('GPU'):
       tf.config.experimental.set_memory_growth(gpu, True)
#gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.6)
#sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
print(tf.test.is_gpu_available())
print(tf.test.is_built_with_cuda())
# Out:
# WARNING:tensorflow:From <ipython-input-7-d8cd39b22d9f>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True
# True

# %% [markdown]
# ## Downloading and preprocessing dataset
#
# We will be using the cifar 10 dataset. It consits of 50000 images (32,32,3) of 10 different classes.

# %%
data = tf.keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = data.load_data()

# %%
# %matplotlib inline
fig, ax = plt.subplots(1, 5)
fig.set_size_inches(16, 6)
for i in range(0,5):
    img = train_images[i]
    ax[i].imshow(img)
    fig.show()
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
print('Image Classes:' + str([x[0] for x in train_labels[0:5]]))
print('Image Labels: ' + str([classes[x[0]] for x in train_labels[0:5]]))


train_images = train_images / 255.0
test_images =  test_images / 255.0

# apparently the OneHotEncoder improves the measurements.... it did...
encoder = OneHotEncoder()
encoder.fit(train_labels)
train_labels = encoder.transform(train_labels).toarray()
test_labels = encoder.transform(test_labels).toarray()
# Out:
# Image Classes:[6, 9, 9, 4, 1]
# Image Labels: ['frog', 'truck', 'truck', 'deer', 'automobile']

# %% [markdown]
# x_norm, will be the dataset used in order to obtain the parameters needed to transform the VGG-13 into a SNN

# %%
x_norm = train_images[np.random.choice(train_images.shape[0], 256, replace=False)]

# %% [markdown]
# ### Data augmentation
# Here we define the data augmentation procedure that will be used for training the model

# %%
data_gen = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=True,
                                                           width_shift_range=0.05,
                                                           height_shift_range=0.05,
                                                           rotation_range=20,
                                                           zoom_range=0.2,
                                                           shear_range=0.1)
data_gen.fit(train_images)

# %% [markdown]
# ## Creating VGG-13 model
#
# We created the vgg-13 model. An Image that deppicts the structure of the model can be found next. The path that deppicts the structure of vgg-13 is the B path. However, since we need to use these architecture weights to construct an SNN, the following constraints most be followed:
#
#
# 1.   The TF model most consist of ReLU layers
# 2.   No bias tensor most be included in the layers
# 3.   Average Pooling Layers most be used. This is because the concept of maximum output is less meaningful when the only values it can take are zero for n = 0 spikes, or one for n > 0 spikes.
# 4. The padding can only be of type valid or same
#
# ![image.png](attachment:image.png)
#
#
# Image taken from https://arxiv.org/abs/1409.1556
#     Authors: Karen Simonyan, Andrew Zisserman

# %%
# Create L2 regularizer
regularizer = tf.keras.regularizers.l2(0.00001) #0.0001
kernel_init = 'he_uniform'

vgg13_model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False, input_shape=(32, 32, 3) ),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Conv2D(256, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(256, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),

    tf.keras.layers.Conv2D(512, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(512, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Conv2D(512, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    #tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(512, (3,3), padding='same', activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.AveragePooling2D((2,2), padding='same'),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(4096, activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax', kernel_initializer=kernel_init, kernel_regularizer=regularizer, use_bias=False)
])

optimizer = tf.keras.optimizers.RMSprop(lr=0.00001, momentum=0.9)
vgg13_model.summary()
vgg13_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 64)        1728
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36864
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73728
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147456
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         294912
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         589824
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 512)         1179648
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         2359296
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 512)         2359296
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 512)         2359296
# _________________________________________________________________
# dropout (Dropout)            (None, 2, 2, 512)         0
# _________________________________________________________________
# average_pooling2d_4 (Average (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2097152
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16777216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                40960
# =================================================================
# Total params: 28,317,376
# Trainable params: 28,317,376
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Epoch 77/200
# 195/195 [==============================] - 26s 134ms/step - loss: 0.6263 - accuracy: 0.9163 - val_loss: 0.7757 - val_accuracy: 0.8912
# optimizer = tf.keras.optimizers.RMSprop(lr=0.00001, momentum=0.9)

# %% [markdown]
# ## Training Model or Load Model
#
# You have to train the model that you craeted in tensorflow as one normally does.

# %%
steps_per_epoch = train_labels.shape[0] // 128

checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1,
                                                 save_best_only=True,
                                                 monitor='val_accuracy')

history = vgg13_model.fit(data_gen.flow(train_images, train_labels, batch_size=128),
           validation_data=(test_images, test_labels), 
           epochs=2,
           steps_per_epoch=steps_per_epoch,
           batch_size=128,
           callbacks=[cp_callback])


checkpoint_path = "training_1/cp.ckpt"

# The model weights (that are considered the best) are loaded into the model.
vgg13_model.load_weights(checkpoint_path)
# Out:
# Epoch 1/200
# 390/390 [==============================] - 68s 85ms/step - loss: 2.5265 - accuracy: 0.1032 - val_loss: 2.4035 - val_accuracy: 0.1000
#
# Epoch 00001: val_accuracy improved from -inf to 0.10000, saving model to training_1/cp.ckpt
# Epoch 2/200
# 390/390 [==============================] - 31s 80ms/step - loss: 2.3938 - accuracy: 0.1052 - val_loss: 2.2840 - val_accuracy: 0.1442
#
# Epoch 00002: val_accuracy improved from 0.10000 to 0.14420, saving model to training_1/cp.ckpt
# Epoch 3/200
# 390/390 [==============================] - 31s 80ms/step - loss: 2.1535 - accuracy: 0.1764 - val_loss: 1.7762 - val_accuracy: 0.3128
#
# Epoch 00003: val_accuracy improved from 0.14420 to 0.31280, saving model to training_1/cp.ckpt
# Epoch 4/200
# 390/390 [==============================] - 31s 80ms/step - loss: 1.8104 - accuracy: 0.3144 - val_loss: 1.6024 - val_accuracy: 0.4132
#
# Epoch 00004: val_accuracy improved from 0.31280 to 0.41320, saving model to training_1/cp.ckpt
# Epoch 5/200
# 390/390 [==============================] - 31s 80ms/step - loss: 1.5971 - accuracy: 0.4253 - val_loss: 1.3627 - val_accuracy: 0.5196
#
# Epoch 00005: val_accuracy improved from 0.41320 to 0.51960, saving model to training_1/cp.ckpt
# Epoch 6/200
# 390/390 [==============================] - 31s 80ms/step - loss: 1.4048 - accuracy: 0.5089 - val_loss: 1.3856 - val_accuracy: 0.5414
#
# Epoch 00006: val_accuracy improved from 0.51960 to 0.54140, saving model to training_1/cp.ckpt
# Epoch 7/200
# 390/390 [==============================] - 31s 80ms/step - loss: 1.2871 - accuracy: 0.5563 - val_loss: 1.1811 - val_accuracy: 0.6180
#
# Epoch 00007: val_accuracy improved from 0.54140 to 0.61800, saving model to training_1/cp.ckpt
# Epoch 8/200
# 390/390 [==============================] - 31s 80ms/step - loss: 1.1691 - accuracy: 0.6065 - val_loss: 1.1062 - val_accuracy: 0.6374
#
# Epoch 00008: val_accuracy improved from 0.61800 to 0.63740, saving model to training_1/cp.ckpt
# Epoch 9/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.0961 - accuracy: 0.6330 - val_loss: 1.0528 - val_accuracy: 0.6649
#
# Epoch 00009: val_accuracy improved from 0.63740 to 0.66490, saving model to training_1/cp.ckpt
# Epoch 10/200
# 390/390 [==============================] - 31s 79ms/step - loss: 1.0152 - accuracy: 0.6657 - val_loss: 0.9886 - val_accuracy: 0.6972
#
# Epoch 00010: val_accuracy improved from 0.66490 to 0.69720, saving model to training_1/cp.ckpt
# Epoch 11/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9665 - accuracy: 0.6890 - val_loss: 0.8699 - val_accuracy: 0.7200
#
# Epoch 00011: val_accuracy improved from 0.69720 to 0.72000, saving model to training_1/cp.ckpt
# Epoch 12/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.9051 - accuracy: 0.7113 - val_loss: 0.9176 - val_accuracy: 0.7204
#
# Epoch 00012: val_accuracy improved from 0.72000 to 0.72040, saving model to training_1/cp.ckpt
# Epoch 13/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8849 - accuracy: 0.7183 - val_loss: 0.9472 - val_accuracy: 0.7172
#
# Epoch 00013: val_accuracy did not improve from 0.72040
# Epoch 14/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.8584 - accuracy: 0.7309 - val_loss: 0.8292 - val_accuracy: 0.7483
#
# Epoch 00014: val_accuracy improved from 0.72040 to 0.74830, saving model to training_1/cp.ckpt
# Epoch 15/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.8113 - accuracy: 0.7471 - val_loss: 0.8495 - val_accuracy: 0.7538
#
# Epoch 00015: val_accuracy improved from 0.74830 to 0.75380, saving model to training_1/cp.ckpt
# Epoch 16/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7784 - accuracy: 0.7648 - val_loss: 0.7464 - val_accuracy: 0.7842
#
# Epoch 00016: val_accuracy improved from 0.75380 to 0.78420, saving model to training_1/cp.ckpt
# Epoch 17/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7551 - accuracy: 0.7675 - val_loss: 0.7658 - val_accuracy: 0.7814
#
# Epoch 00017: val_accuracy did not improve from 0.78420
# Epoch 18/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.7273 - accuracy: 0.7801 - val_loss: 0.7078 - val_accuracy: 0.8001
#
# Epoch 00018: val_accuracy improved from 0.78420 to 0.80010, saving model to training_1/cp.ckpt
# Epoch 19/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.7142 - accuracy: 0.7871 - val_loss: 0.8087 - val_accuracy: 0.7711
#
# Epoch 00019: val_accuracy did not improve from 0.80010
# Epoch 20/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6980 - accuracy: 0.7920 - val_loss: 0.7563 - val_accuracy: 0.7906
#
# Epoch 00020: val_accuracy did not improve from 0.80010
# Epoch 21/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.6972 - accuracy: 0.7946 - val_loss: 0.6801 - val_accuracy: 0.8056
#
# Epoch 00021: val_accuracy improved from 0.80010 to 0.80560, saving model to training_1/cp.ckpt
# Epoch 22/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.6602 - accuracy: 0.8060 - val_loss: 0.7914 - val_accuracy: 0.7872
#
# Epoch 00022: val_accuracy did not improve from 0.80560
# Epoch 23/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6587 - accuracy: 0.8099 - val_loss: 0.7354 - val_accuracy: 0.8040
#
# Epoch 00023: val_accuracy did not improve from 0.80560
# Epoch 24/200
# 390/390 [==============================] - 30s 78ms/step - loss: 0.6440 - accuracy: 0.8135 - val_loss: 0.6935 - val_accuracy: 0.8127
#
# Epoch 00024: val_accuracy improved from 0.80560 to 0.81270, saving model to training_1/cp.ckpt
# Epoch 25/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6403 - accuracy: 0.8200 - val_loss: 0.6798 - val_accuracy: 0.8274
#
# Epoch 00025: val_accuracy improved from 0.81270 to 0.82740, saving model to training_1/cp.ckpt
# Epoch 26/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6188 - accuracy: 0.8249 - val_loss: 0.7311 - val_accuracy: 0.8131
#
# Epoch 00026: val_accuracy did not improve from 0.82740
# Epoch 27/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.6317 - accuracy: 0.8205 - val_loss: 0.6783 - val_accuracy: 0.8101
#
# Epoch 00027: val_accuracy did not improve from 0.82740
# Epoch 28/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5915 - accuracy: 0.8323 - val_loss: 0.7170 - val_accuracy: 0.8165
#
# Epoch 00028: val_accuracy did not improve from 0.82740
# Epoch 29/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5995 - accuracy: 0.8295 - val_loss: 0.6225 - val_accuracy: 0.8357
#
# Epoch 00029: val_accuracy improved from 0.82740 to 0.83570, saving model to training_1/cp.ckpt
# Epoch 30/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5823 - accuracy: 0.8409 - val_loss: 0.7542 - val_accuracy: 0.8064
#
# Epoch 00030: val_accuracy did not improve from 0.83570
# Epoch 31/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5806 - accuracy: 0.8399 - val_loss: 0.6971 - val_accuracy: 0.8210
#
# Epoch 00031: val_accuracy did not improve from 0.83570
# Epoch 32/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5765 - accuracy: 0.8427 - val_loss: 0.6522 - val_accuracy: 0.8313
#
# Epoch 00032: val_accuracy did not improve from 0.83570
# Epoch 33/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5750 - accuracy: 0.8445 - val_loss: 0.6295 - val_accuracy: 0.8438
#
# Epoch 00033: val_accuracy improved from 0.83570 to 0.84380, saving model to training_1/cp.ckpt
# Epoch 34/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5650 - accuracy: 0.8463 - val_loss: 0.6590 - val_accuracy: 0.8333
#
# Epoch 00034: val_accuracy did not improve from 0.84380
# Epoch 35/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5536 - accuracy: 0.8537 - val_loss: 0.6603 - val_accuracy: 0.8345
#
# Epoch 00035: val_accuracy did not improve from 0.84380
# Epoch 36/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5600 - accuracy: 0.8513 - val_loss: 0.6079 - val_accuracy: 0.8371
#
# Epoch 00036: val_accuracy did not improve from 0.84380
# Epoch 37/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5502 - accuracy: 0.8545 - val_loss: 0.6184 - val_accuracy: 0.8442
#
# Epoch 00037: val_accuracy improved from 0.84380 to 0.84420, saving model to training_1/cp.ckpt
# Epoch 38/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5390 - accuracy: 0.8580 - val_loss: 0.6519 - val_accuracy: 0.8349
#
# Epoch 00038: val_accuracy did not improve from 0.84420
# Epoch 39/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5293 - accuracy: 0.8598 - val_loss: 0.6430 - val_accuracy: 0.8378
#
# Epoch 00039: val_accuracy did not improve from 0.84420
# Epoch 40/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5302 - accuracy: 0.8628 - val_loss: 0.6839 - val_accuracy: 0.8319
#
# Epoch 00040: val_accuracy did not improve from 0.84420
# Epoch 41/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5281 - accuracy: 0.8595 - val_loss: 0.6126 - val_accuracy: 0.8482
#
# Epoch 00041: val_accuracy improved from 0.84420 to 0.84820, saving model to training_1/cp.ckpt
# Epoch 42/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5228 - accuracy: 0.8621 - val_loss: 0.6407 - val_accuracy: 0.8492
#
# Epoch 00042: val_accuracy improved from 0.84820 to 0.84920, saving model to training_1/cp.ckpt
# Epoch 43/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5168 - accuracy: 0.8669 - val_loss: 0.6492 - val_accuracy: 0.8425
#
# Epoch 00043: val_accuracy did not improve from 0.84920
# Epoch 44/200
# 390/390 [==============================] - 31s 78ms/step - loss: 0.5225 - accuracy: 0.8675 - val_loss: 0.6384 - val_accuracy: 0.8539
#
# Epoch 00044: val_accuracy improved from 0.84920 to 0.85390, saving model to training_1/cp.ckpt
# Epoch 45/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5010 - accuracy: 0.8751 - val_loss: 0.6441 - val_accuracy: 0.8458
#
# Epoch 00045: val_accuracy did not improve from 0.85390
# Epoch 46/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5093 - accuracy: 0.8707 - val_loss: 0.5911 - val_accuracy: 0.8626
#
# Epoch 00046: val_accuracy improved from 0.85390 to 0.86260, saving model to training_1/cp.ckpt
# Epoch 47/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5011 - accuracy: 0.8755 - val_loss: 0.6409 - val_accuracy: 0.8561
#
# Epoch 00047: val_accuracy did not improve from 0.86260
# Epoch 48/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4961 - accuracy: 0.8763 - val_loss: 0.6222 - val_accuracy: 0.8536
#
# Epoch 00048: val_accuracy did not improve from 0.86260
# Epoch 49/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4956 - accuracy: 0.8774 - val_loss: 0.6117 - val_accuracy: 0.8547
#
# Epoch 00049: val_accuracy did not improve from 0.86260
# Epoch 50/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4884 - accuracy: 0.8780 - val_loss: 0.6309 - val_accuracy: 0.8552
#
# Epoch 00050: val_accuracy did not improve from 0.86260
# Epoch 51/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4987 - accuracy: 0.8760 - val_loss: 0.6868 - val_accuracy: 0.8373
#
# Epoch 00051: val_accuracy did not improve from 0.86260
# Epoch 52/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4901 - accuracy: 0.8778 - val_loss: 0.6585 - val_accuracy: 0.8449
#
# Epoch 00052: val_accuracy did not improve from 0.86260
# Epoch 53/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4812 - accuracy: 0.8816 - val_loss: 0.5761 - val_accuracy: 0.8594
#
# Epoch 00053: val_accuracy did not improve from 0.86260
# Epoch 54/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4821 - accuracy: 0.8835 - val_loss: 0.6194 - val_accuracy: 0.8633
#
# Epoch 00054: val_accuracy improved from 0.86260 to 0.86330, saving model to training_1/cp.ckpt
# Epoch 55/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4814 - accuracy: 0.8863 - val_loss: 0.6121 - val_accuracy: 0.8560
#
# Epoch 00055: val_accuracy did not improve from 0.86330
# Epoch 56/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4831 - accuracy: 0.8826 - val_loss: 0.5854 - val_accuracy: 0.8682
#
# Epoch 00056: val_accuracy improved from 0.86330 to 0.86820, saving model to training_1/cp.ckpt
# Epoch 57/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4774 - accuracy: 0.8838 - val_loss: 0.6043 - val_accuracy: 0.8636
#
# Epoch 00057: val_accuracy did not improve from 0.86820
# Epoch 58/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4659 - accuracy: 0.8897 - val_loss: 0.6297 - val_accuracy: 0.8585
#
# Epoch 00058: val_accuracy did not improve from 0.86820
# Epoch 59/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4705 - accuracy: 0.8894 - val_loss: 0.6817 - val_accuracy: 0.8478
#
# Epoch 00059: val_accuracy did not improve from 0.86820
# Epoch 60/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4678 - accuracy: 0.8894 - val_loss: 0.6630 - val_accuracy: 0.8623
#
# Epoch 00060: val_accuracy did not improve from 0.86820
# Epoch 61/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4653 - accuracy: 0.8900 - val_loss: 0.6535 - val_accuracy: 0.8575
#
# Epoch 00061: val_accuracy did not improve from 0.86820
# Epoch 62/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4677 - accuracy: 0.8900 - val_loss: 0.6652 - val_accuracy: 0.8589
#
# Epoch 00062: val_accuracy did not improve from 0.86820
# Epoch 63/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4645 - accuracy: 0.8937 - val_loss: 0.6588 - val_accuracy: 0.8584
#
# Epoch 00063: val_accuracy did not improve from 0.86820
# Epoch 64/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4617 - accuracy: 0.8908 - val_loss: 0.6328 - val_accuracy: 0.8629
#
# Epoch 00064: val_accuracy did not improve from 0.86820
# Epoch 65/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4604 - accuracy: 0.8925 - val_loss: 0.6839 - val_accuracy: 0.8567
#
# Epoch 00065: val_accuracy did not improve from 0.86820
# Epoch 66/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4674 - accuracy: 0.8921 - val_loss: 0.7055 - val_accuracy: 0.8572
#
# Epoch 00066: val_accuracy did not improve from 0.86820
# Epoch 67/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4595 - accuracy: 0.8941 - val_loss: 0.6620 - val_accuracy: 0.8634
#
# Epoch 00067: val_accuracy did not improve from 0.86820
# Epoch 68/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4538 - accuracy: 0.8945 - val_loss: 0.6470 - val_accuracy: 0.8660
#
# Epoch 00068: val_accuracy did not improve from 0.86820
# Epoch 69/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4582 - accuracy: 0.8956 - val_loss: 0.6169 - val_accuracy: 0.8618
#
# Epoch 00069: val_accuracy did not improve from 0.86820
# Epoch 70/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4584 - accuracy: 0.8951 - val_loss: 0.6420 - val_accuracy: 0.8610
#
# Epoch 00070: val_accuracy did not improve from 0.86820
# Epoch 71/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4595 - accuracy: 0.8979 - val_loss: 0.6164 - val_accuracy: 0.8653
#
# Epoch 00071: val_accuracy did not improve from 0.86820
# Epoch 72/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4548 - accuracy: 0.9004 - val_loss: 0.6260 - val_accuracy: 0.8682
#
# Epoch 00072: val_accuracy did not improve from 0.86820
# Epoch 73/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4464 - accuracy: 0.9032 - val_loss: 0.6426 - val_accuracy: 0.8555
#
# Epoch 00073: val_accuracy did not improve from 0.86820
# Epoch 74/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4434 - accuracy: 0.9051 - val_loss: 0.6733 - val_accuracy: 0.8585
#
# Epoch 00074: val_accuracy did not improve from 0.86820
# Epoch 75/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4553 - accuracy: 0.8980 - val_loss: 0.6092 - val_accuracy: 0.8694
#
# Epoch 00075: val_accuracy improved from 0.86820 to 0.86940, saving model to training_1/cp.ckpt
# Epoch 76/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4444 - accuracy: 0.9033 - val_loss: 0.6033 - val_accuracy: 0.8683
#
# Epoch 00076: val_accuracy did not improve from 0.86940
# Epoch 77/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4420 - accuracy: 0.9054 - val_loss: 0.6102 - val_accuracy: 0.8713
#
# Epoch 00077: val_accuracy improved from 0.86940 to 0.87130, saving model to training_1/cp.ckpt
# Epoch 78/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4514 - accuracy: 0.9013 - val_loss: 0.5841 - val_accuracy: 0.8736
#
# Epoch 00078: val_accuracy improved from 0.87130 to 0.87360, saving model to training_1/cp.ckpt
# Epoch 79/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4358 - accuracy: 0.9052 - val_loss: 0.6107 - val_accuracy: 0.8689
#
# Epoch 00079: val_accuracy did not improve from 0.87360
# Epoch 80/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4415 - accuracy: 0.9064 - val_loss: 0.6651 - val_accuracy: 0.8638
#
# Epoch 00080: val_accuracy did not improve from 0.87360
# Epoch 81/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4573 - accuracy: 0.8999 - val_loss: 0.6931 - val_accuracy: 0.8529
#
# Epoch 00081: val_accuracy did not improve from 0.87360
# Epoch 82/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4447 - accuracy: 0.9056 - val_loss: 0.6898 - val_accuracy: 0.8620
#
# Epoch 00082: val_accuracy did not improve from 0.87360
# Epoch 83/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4380 - accuracy: 0.9074 - val_loss: 0.5677 - val_accuracy: 0.8798
#
# Epoch 00083: val_accuracy improved from 0.87360 to 0.87980, saving model to training_1/cp.ckpt
# Epoch 84/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4356 - accuracy: 0.9088 - val_loss: 0.6093 - val_accuracy: 0.8744
#
# Epoch 00084: val_accuracy did not improve from 0.87980
# Epoch 85/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4281 - accuracy: 0.9100 - val_loss: 0.6403 - val_accuracy: 0.8653
#
# Epoch 00085: val_accuracy did not improve from 0.87980
# Epoch 86/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4346 - accuracy: 0.9064 - val_loss: 0.6287 - val_accuracy: 0.8714
#
# Epoch 00086: val_accuracy did not improve from 0.87980
# Epoch 87/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4349 - accuracy: 0.9077 - val_loss: 0.6410 - val_accuracy: 0.8711
#
# Epoch 00087: val_accuracy did not improve from 0.87980
# Epoch 88/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4355 - accuracy: 0.9089 - val_loss: 0.6268 - val_accuracy: 0.8734
#
# Epoch 00088: val_accuracy did not improve from 0.87980
# Epoch 89/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4360 - accuracy: 0.9098 - val_loss: 0.6325 - val_accuracy: 0.8719
#
# Epoch 00089: val_accuracy did not improve from 0.87980
# Epoch 90/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4329 - accuracy: 0.9110 - val_loss: 0.6352 - val_accuracy: 0.8698
#
# Epoch 00090: val_accuracy did not improve from 0.87980
# Epoch 91/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4386 - accuracy: 0.9085 - val_loss: 0.6369 - val_accuracy: 0.8698
#
# Epoch 00091: val_accuracy did not improve from 0.87980
# Epoch 92/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4260 - accuracy: 0.9132 - val_loss: 0.7056 - val_accuracy: 0.8619
#
# Epoch 00092: val_accuracy did not improve from 0.87980
# Epoch 93/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4327 - accuracy: 0.9087 - val_loss: 0.6596 - val_accuracy: 0.8686
#
# Epoch 00093: val_accuracy did not improve from 0.87980
# Epoch 94/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4381 - accuracy: 0.9102 - val_loss: 0.6498 - val_accuracy: 0.8754
#
# Epoch 00094: val_accuracy did not improve from 0.87980
# Epoch 95/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4290 - accuracy: 0.9131 - val_loss: 0.6882 - val_accuracy: 0.8685
#
# Epoch 00095: val_accuracy did not improve from 0.87980
# Epoch 96/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4168 - accuracy: 0.9194 - val_loss: 0.6903 - val_accuracy: 0.8731
#
# Epoch 00096: val_accuracy did not improve from 0.87980
# Epoch 97/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4211 - accuracy: 0.9147 - val_loss: 0.6018 - val_accuracy: 0.8800
#
# Epoch 00097: val_accuracy improved from 0.87980 to 0.88000, saving model to training_1/cp.ckpt
# Epoch 98/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4235 - accuracy: 0.9143 - val_loss: 0.7015 - val_accuracy: 0.8707
#
# Epoch 00098: val_accuracy did not improve from 0.88000
# Epoch 99/200
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4353 - accuracy: 0.9115 - val_loss: 0.6320 - val_accuracy: 0.8757
#
# Epoch 00099: val_accuracy did not improve from 0.88000
# Epoch 100/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4313 - accuracy: 0.9146 - val_loss: 0.6277 - val_accuracy: 0.8682
#
# Epoch 00100: val_accuracy did not improve from 0.88000
# Epoch 101/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4270 - accuracy: 0.9147 - val_loss: 0.6595 - val_accuracy: 0.8813
#
# Epoch 00101: val_accuracy improved from 0.88000 to 0.88130, saving model to training_1/cp.ckpt
# Epoch 102/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4154 - accuracy: 0.9173 - val_loss: 0.6338 - val_accuracy: 0.8736
#
# Epoch 00102: val_accuracy did not improve from 0.88130
# Epoch 103/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4138 - accuracy: 0.9203 - val_loss: 0.6463 - val_accuracy: 0.8713
#
# Epoch 00103: val_accuracy did not improve from 0.88130
# Epoch 104/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4249 - accuracy: 0.9149 - val_loss: 0.6821 - val_accuracy: 0.8719
#
# Epoch 00104: val_accuracy did not improve from 0.88130
# Epoch 105/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4278 - accuracy: 0.9165 - val_loss: 0.7039 - val_accuracy: 0.8646
#
# Epoch 00105: val_accuracy did not improve from 0.88130
# Epoch 106/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4157 - accuracy: 0.9178 - val_loss: 0.6392 - val_accuracy: 0.8771
#
# Epoch 00106: val_accuracy did not improve from 0.88130
# Epoch 107/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4263 - accuracy: 0.9140 - val_loss: 0.6800 - val_accuracy: 0.8765
#
# Epoch 00107: val_accuracy did not improve from 0.88130
# Epoch 108/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4217 - accuracy: 0.9191 - val_loss: 0.7341 - val_accuracy: 0.8639
#
# Epoch 00108: val_accuracy did not improve from 0.88130
# Epoch 109/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4282 - accuracy: 0.9167 - val_loss: 0.6451 - val_accuracy: 0.8822
#
# Epoch 00109: val_accuracy improved from 0.88130 to 0.88220, saving model to training_1/cp.ckpt
# Epoch 110/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4194 - accuracy: 0.9188 - val_loss: 0.6457 - val_accuracy: 0.8680
#
# Epoch 00110: val_accuracy did not improve from 0.88220
# Epoch 111/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4294 - accuracy: 0.9182 - val_loss: 0.6514 - val_accuracy: 0.8820
#
# Epoch 00111: val_accuracy did not improve from 0.88220
# Epoch 112/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4149 - accuracy: 0.9230 - val_loss: 0.6616 - val_accuracy: 0.8786
#
# Epoch 00112: val_accuracy did not improve from 0.88220
# Epoch 113/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4100 - accuracy: 0.9233 - val_loss: 0.7187 - val_accuracy: 0.8731
#
# Epoch 00113: val_accuracy did not improve from 0.88220
# Epoch 114/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4125 - accuracy: 0.9226 - val_loss: 0.6528 - val_accuracy: 0.8864
#
# Epoch 00114: val_accuracy improved from 0.88220 to 0.88640, saving model to training_1/cp.ckpt
# Epoch 115/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4119 - accuracy: 0.9220 - val_loss: 0.6483 - val_accuracy: 0.8786
#
# Epoch 00115: val_accuracy did not improve from 0.88640
# Epoch 116/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4122 - accuracy: 0.9228 - val_loss: 0.6908 - val_accuracy: 0.8771
#
# Epoch 00116: val_accuracy did not improve from 0.88640
# Epoch 117/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4225 - accuracy: 0.9214 - val_loss: 0.6816 - val_accuracy: 0.8636
#
# Epoch 00117: val_accuracy did not improve from 0.88640
# Epoch 118/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4185 - accuracy: 0.9237 - val_loss: 0.6649 - val_accuracy: 0.8861
#
# Epoch 00118: val_accuracy did not improve from 0.88640
# Epoch 119/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4162 - accuracy: 0.9239 - val_loss: 0.6606 - val_accuracy: 0.8705
#
# Epoch 00119: val_accuracy did not improve from 0.88640
# Epoch 120/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4146 - accuracy: 0.9231 - val_loss: 0.7215 - val_accuracy: 0.8780
#
# Epoch 00120: val_accuracy did not improve from 0.88640
# Epoch 121/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4122 - accuracy: 0.9221 - val_loss: 0.6582 - val_accuracy: 0.8790
#
# Epoch 00121: val_accuracy did not improve from 0.88640
# Epoch 122/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4128 - accuracy: 0.9236 - val_loss: 0.6796 - val_accuracy: 0.8657
#
# Epoch 00122: val_accuracy did not improve from 0.88640
# Epoch 123/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4192 - accuracy: 0.9230 - val_loss: 0.6683 - val_accuracy: 0.8816
#
# Epoch 00123: val_accuracy did not improve from 0.88640
# Epoch 124/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4117 - accuracy: 0.9245 - val_loss: 0.7870 - val_accuracy: 0.8767
#
# Epoch 00124: val_accuracy did not improve from 0.88640
# Epoch 125/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4122 - accuracy: 0.9233 - val_loss: 0.6664 - val_accuracy: 0.8833
#
# Epoch 00125: val_accuracy did not improve from 0.88640
# Epoch 126/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4115 - accuracy: 0.9240 - val_loss: 0.7069 - val_accuracy: 0.8628
#
# Epoch 00126: val_accuracy did not improve from 0.88640
# Epoch 127/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4167 - accuracy: 0.9211 - val_loss: 0.6647 - val_accuracy: 0.8738
#
# Epoch 00127: val_accuracy did not improve from 0.88640
# Epoch 128/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4088 - accuracy: 0.9250 - val_loss: 0.6475 - val_accuracy: 0.8780
#
# Epoch 00128: val_accuracy did not improve from 0.88640
# Epoch 129/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4068 - accuracy: 0.9256 - val_loss: 0.7067 - val_accuracy: 0.8789
#
# Epoch 00129: val_accuracy did not improve from 0.88640
# Epoch 130/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4130 - accuracy: 0.9248 - val_loss: 0.7506 - val_accuracy: 0.8676
#
# Epoch 00130: val_accuracy did not improve from 0.88640
# Epoch 131/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4108 - accuracy: 0.9260 - val_loss: 0.6511 - val_accuracy: 0.8836
#
# Epoch 00131: val_accuracy did not improve from 0.88640
# Epoch 132/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4009 - accuracy: 0.9273 - val_loss: 0.6405 - val_accuracy: 0.8853
#
# Epoch 00132: val_accuracy did not improve from 0.88640
# Epoch 133/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4071 - accuracy: 0.9273 - val_loss: 0.6987 - val_accuracy: 0.8641
#
# Epoch 00133: val_accuracy did not improve from 0.88640
# Epoch 134/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4116 - accuracy: 0.9263 - val_loss: 0.7658 - val_accuracy: 0.8685
#
# Epoch 00134: val_accuracy did not improve from 0.88640
# Epoch 135/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4098 - accuracy: 0.9251 - val_loss: 0.6224 - val_accuracy: 0.8825
#
# Epoch 00135: val_accuracy did not improve from 0.88640
# Epoch 136/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4050 - accuracy: 0.9264 - val_loss: 0.6582 - val_accuracy: 0.8825
#
# Epoch 00136: val_accuracy did not improve from 0.88640
# Epoch 137/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4119 - accuracy: 0.9265 - val_loss: 0.6626 - val_accuracy: 0.8801
#
# Epoch 00137: val_accuracy did not improve from 0.88640
# Epoch 138/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4067 - accuracy: 0.9286 - val_loss: 0.7036 - val_accuracy: 0.8757
#
# Epoch 00138: val_accuracy did not improve from 0.88640
# Epoch 139/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4232 - accuracy: 0.9240 - val_loss: 0.6844 - val_accuracy: 0.8774
#
# Epoch 00139: val_accuracy did not improve from 0.88640
# Epoch 140/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4015 - accuracy: 0.9275 - val_loss: 0.7747 - val_accuracy: 0.8706
#
# Epoch 00140: val_accuracy did not improve from 0.88640
# Epoch 141/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4015 - accuracy: 0.9284 - val_loss: 0.6599 - val_accuracy: 0.8843
#
# Epoch 00141: val_accuracy did not improve from 0.88640
# Epoch 142/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4048 - accuracy: 0.9274 - val_loss: 0.6555 - val_accuracy: 0.8857
#
# Epoch 00142: val_accuracy did not improve from 0.88640
# Epoch 143/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4052 - accuracy: 0.9290 - val_loss: 0.6490 - val_accuracy: 0.8801
#
# Epoch 00143: val_accuracy did not improve from 0.88640
# Epoch 144/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4014 - accuracy: 0.9290 - val_loss: 0.7032 - val_accuracy: 0.8729
#
# Epoch 00144: val_accuracy did not improve from 0.88640
# Epoch 145/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4029 - accuracy: 0.9301 - val_loss: 0.6636 - val_accuracy: 0.8806
#
# Epoch 00145: val_accuracy did not improve from 0.88640
# Epoch 146/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4028 - accuracy: 0.9309 - val_loss: 0.6748 - val_accuracy: 0.8781
#
# Epoch 00146: val_accuracy did not improve from 0.88640
# Epoch 147/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4084 - accuracy: 0.9268 - val_loss: 0.7142 - val_accuracy: 0.8722
#
# Epoch 00147: val_accuracy did not improve from 0.88640
# Epoch 148/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4031 - accuracy: 0.9296 - val_loss: 0.6108 - val_accuracy: 0.8816
#
# Epoch 00148: val_accuracy did not improve from 0.88640
# Epoch 149/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4115 - accuracy: 0.9266 - val_loss: 0.6485 - val_accuracy: 0.8792
#
# Epoch 00149: val_accuracy did not improve from 0.88640
# Epoch 150/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4148 - accuracy: 0.9273 - val_loss: 0.7141 - val_accuracy: 0.8749
#
# Epoch 00150: val_accuracy did not improve from 0.88640
# Epoch 151/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3979 - accuracy: 0.9311 - val_loss: 0.7645 - val_accuracy: 0.8660
#
# Epoch 00151: val_accuracy did not improve from 0.88640
# Epoch 152/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4183 - accuracy: 0.9233 - val_loss: 0.7369 - val_accuracy: 0.8665
#
# Epoch 00152: val_accuracy did not improve from 0.88640
# Epoch 153/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4171 - accuracy: 0.9264 - val_loss: 0.6607 - val_accuracy: 0.8841
#
# Epoch 00153: val_accuracy did not improve from 0.88640
# Epoch 154/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4008 - accuracy: 0.9296 - val_loss: 0.6677 - val_accuracy: 0.8833
#
# Epoch 00154: val_accuracy did not improve from 0.88640
# Epoch 155/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4001 - accuracy: 0.9302 - val_loss: 0.7178 - val_accuracy: 0.8700
#
# Epoch 00155: val_accuracy did not improve from 0.88640
# Epoch 156/200
# 390/390 [==============================] - 31s 80ms/step - loss: 0.4026 - accuracy: 0.9297 - val_loss: 0.6314 - val_accuracy: 0.8866
#
# Epoch 00156: val_accuracy improved from 0.88640 to 0.88660, saving model to training_1/cp.ckpt
# Epoch 157/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4012 - accuracy: 0.9337 - val_loss: 0.7340 - val_accuracy: 0.8723
#
# Epoch 00157: val_accuracy did not improve from 0.88660
# Epoch 158/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4011 - accuracy: 0.9304 - val_loss: 0.7188 - val_accuracy: 0.8749
#
# Epoch 00158: val_accuracy did not improve from 0.88660
# Epoch 159/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3993 - accuracy: 0.9341 - val_loss: 0.7070 - val_accuracy: 0.8823
#
# Epoch 00159: val_accuracy did not improve from 0.88660
# Epoch 160/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4046 - accuracy: 0.9329 - val_loss: 0.6238 - val_accuracy: 0.8881
#
# Epoch 00160: val_accuracy improved from 0.88660 to 0.88810, saving model to training_1/cp.ckpt
# Epoch 161/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3917 - accuracy: 0.9335 - val_loss: 0.7440 - val_accuracy: 0.8770
#
# Epoch 00161: val_accuracy did not improve from 0.88810
# Epoch 162/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4086 - accuracy: 0.9301 - val_loss: 0.7663 - val_accuracy: 0.8806
#
# Epoch 00162: val_accuracy did not improve from 0.88810
# Epoch 163/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3996 - accuracy: 0.9318 - val_loss: 0.7144 - val_accuracy: 0.8850
#
# Epoch 00163: val_accuracy did not improve from 0.88810
# Epoch 164/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4068 - accuracy: 0.9327 - val_loss: 0.6697 - val_accuracy: 0.8789
#
# Epoch 00164: val_accuracy did not improve from 0.88810
# Epoch 165/200
# 390/390 [==============================] - 31s 81ms/step - loss: 0.4052 - accuracy: 0.9318 - val_loss: 0.6341 - val_accuracy: 0.8806
#
# Epoch 00165: val_accuracy did not improve from 0.88810
# Epoch 166/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4014 - accuracy: 0.9312 - val_loss: 0.7452 - val_accuracy: 0.8818
#
# Epoch 00166: val_accuracy did not improve from 0.88810
# Epoch 167/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4005 - accuracy: 0.9322 - val_loss: 0.7265 - val_accuracy: 0.8816
#
# Epoch 00167: val_accuracy did not improve from 0.88810
# Epoch 168/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4077 - accuracy: 0.9314 - val_loss: 0.6914 - val_accuracy: 0.8800
#
# Epoch 00168: val_accuracy did not improve from 0.88810
# Epoch 169/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4042 - accuracy: 0.9315 - val_loss: 0.7053 - val_accuracy: 0.8774
#
# Epoch 00169: val_accuracy did not improve from 0.88810
# Epoch 170/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3969 - accuracy: 0.9349 - val_loss: 0.6574 - val_accuracy: 0.8850
#
# Epoch 00170: val_accuracy did not improve from 0.88810
# Epoch 171/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3993 - accuracy: 0.9339 - val_loss: 0.6559 - val_accuracy: 0.8853
#
# Epoch 00171: val_accuracy did not improve from 0.88810
# Epoch 172/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3998 - accuracy: 0.9334 - val_loss: 0.6795 - val_accuracy: 0.8795
#
# Epoch 00172: val_accuracy did not improve from 0.88810
# Epoch 173/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3950 - accuracy: 0.9357 - val_loss: 0.6800 - val_accuracy: 0.8827
#
# Epoch 00173: val_accuracy did not improve from 0.88810
# Epoch 174/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3988 - accuracy: 0.9328 - val_loss: 0.7411 - val_accuracy: 0.8787
#
# Epoch 00174: val_accuracy did not improve from 0.88810
# Epoch 175/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4004 - accuracy: 0.9314 - val_loss: 0.6444 - val_accuracy: 0.8891
#
# Epoch 00175: val_accuracy improved from 0.88810 to 0.88910, saving model to training_1/cp.ckpt
# Epoch 176/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3928 - accuracy: 0.9359 - val_loss: 0.6178 - val_accuracy: 0.8863
#
# Epoch 00176: val_accuracy did not improve from 0.88910
# Epoch 177/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3999 - accuracy: 0.9349 - val_loss: 0.7621 - val_accuracy: 0.8754
#
# Epoch 00177: val_accuracy did not improve from 0.88910
# Epoch 178/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4003 - accuracy: 0.9339 - val_loss: 0.6928 - val_accuracy: 0.8794
#
# Epoch 00178: val_accuracy did not improve from 0.88910
# Epoch 179/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3880 - accuracy: 0.9366 - val_loss: 0.6587 - val_accuracy: 0.8874
#
# Epoch 00179: val_accuracy did not improve from 0.88910
# Epoch 180/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4074 - accuracy: 0.9329 - val_loss: 0.8839 - val_accuracy: 0.8767
#
# Epoch 00180: val_accuracy did not improve from 0.88910
# Epoch 181/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4025 - accuracy: 0.9350 - val_loss: 0.6899 - val_accuracy: 0.8760
#
# Epoch 00181: val_accuracy did not improve from 0.88910
# Epoch 182/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3922 - accuracy: 0.9370 - val_loss: 0.6833 - val_accuracy: 0.8843
#
# Epoch 00182: val_accuracy did not improve from 0.88910
# Epoch 183/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3870 - accuracy: 0.9381 - val_loss: 0.6646 - val_accuracy: 0.8847
#
# Epoch 00183: val_accuracy did not improve from 0.88910
# Epoch 184/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3974 - accuracy: 0.9354 - val_loss: 0.6497 - val_accuracy: 0.8814
#
# Epoch 00184: val_accuracy did not improve from 0.88910
# Epoch 185/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4050 - accuracy: 0.9330 - val_loss: 0.6994 - val_accuracy: 0.8750
#
# Epoch 00185: val_accuracy did not improve from 0.88910
# Epoch 186/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4009 - accuracy: 0.9342 - val_loss: 0.7228 - val_accuracy: 0.8832
#
# Epoch 00186: val_accuracy did not improve from 0.88910
# Epoch 187/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4034 - accuracy: 0.9328 - val_loss: 0.6987 - val_accuracy: 0.8868
#
# Epoch 00187: val_accuracy did not improve from 0.88910
# Epoch 188/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3865 - accuracy: 0.9379 - val_loss: 0.7178 - val_accuracy: 0.8738
#
# Epoch 00188: val_accuracy did not improve from 0.88910
# Epoch 189/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4060 - accuracy: 0.9333 - val_loss: 0.6746 - val_accuracy: 0.8833
#
# Epoch 00189: val_accuracy did not improve from 0.88910
# Epoch 190/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4038 - accuracy: 0.9348 - val_loss: 0.7333 - val_accuracy: 0.8827
#
# Epoch 00190: val_accuracy did not improve from 0.88910
# Epoch 191/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3907 - accuracy: 0.9369 - val_loss: 0.7746 - val_accuracy: 0.8730
#
# Epoch 00191: val_accuracy did not improve from 0.88910
# Epoch 192/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.4011 - accuracy: 0.9342 - val_loss: 0.6923 - val_accuracy: 0.8957
#
# Epoch 00192: val_accuracy improved from 0.88910 to 0.89570, saving model to training_1/cp.ckpt
# Epoch 193/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4000 - accuracy: 0.9353 - val_loss: 0.7127 - val_accuracy: 0.8766
#
# Epoch 00193: val_accuracy did not improve from 0.89570
# Epoch 194/200
# 390/390 [==============================] - 32s 81ms/step - loss: 0.3862 - accuracy: 0.9394 - val_loss: 0.6534 - val_accuracy: 0.8870
#
# Epoch 00194: val_accuracy did not improve from 0.89570
# Epoch 195/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3954 - accuracy: 0.9387 - val_loss: 0.6718 - val_accuracy: 0.8861
#
# Epoch 00195: val_accuracy did not improve from 0.89570
# Epoch 196/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3866 - accuracy: 0.9396 - val_loss: 0.7582 - val_accuracy: 0.8749
#
# Epoch 00196: val_accuracy did not improve from 0.89570
# Epoch 197/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3901 - accuracy: 0.9370 - val_loss: 0.6863 - val_accuracy: 0.8787
#
# Epoch 00197: val_accuracy did not improve from 0.89570
# Epoch 198/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.4062 - accuracy: 0.9334 - val_loss: 0.6845 - val_accuracy: 0.8772
#
# Epoch 00198: val_accuracy did not improve from 0.89570
# Epoch 199/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3899 - accuracy: 0.9399 - val_loss: 0.6731 - val_accuracy: 0.8921
#
# Epoch 00199: val_accuracy did not improve from 0.89570
# Epoch 200/200
# 390/390 [==============================] - 32s 82ms/step - loss: 0.3995 - accuracy: 0.9363 - val_loss: 0.7536 - val_accuracy: 0.8784
#
# Epoch 00200: val_accuracy did not improve from 0.89570

# %%
LOAD_MODEL = True

if LOAD_MODEL:
    vgg13_model = tf.keras.models.load_model('vgg13_tf_model')

else:
    steps_per_epoch = train_labels.shape[0] // 128

    checkpoint_path = "training_1/cp.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)

    # Create a callback that saves the model's weights
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                     save_weights_only=True,
                                                     verbose=1,
                                                     save_best_only=True,
                                                     monitor='val_accuracy')

    history = vgg13_model.fit(data_gen.flow(train_images, train_labels, batch_size=128),
               validation_data=(test_images, test_labels), 
               epochs=2,
               steps_per_epoch=steps_per_epoch,
               batch_size=128,
               callbacks=[cp_callback])


    checkpoint_path = "training_1/cp.ckpt"

    # The model weights (that are considered the best) are loaded into the model.
    vgg13_model.load_weights(checkpoint_path)

# %% [markdown]
# The current model that we worked in got an validation accuracy of 89.5% as shown below

# %%
tf_eval_start_time = perf_counter()
vgg13_model.evaluate(test_images, test_labels)
print("TF evaluation:%f" % (perf_counter() - tf_eval_start_time))
# Out:
# 313/313 [==============================] - 4s 6ms/step - loss: 0.6839 - accuracy: 0.8957
# TF evaluation:3.945834

# %% [markdown]
# ## Transform the model to an SNN

# %% [markdown]
# Here are the parameters that can be used for the rate based conversion:
#
# Here are the normalization methods that most be used:
#
#
# ## Encoding technique used for input data transformation
#
# The input data of an SNN most be encoded in order for it to be fed to an SNN. This allows the networks to have pseudo-simultaneity of input and output, time-varying inputs can be more efficiently processed and more efficient computation can be obtained. These are the techniques that you may use for encoding your input data:
#
# - Spike input neurons : 'spike'
# - Spike input neurons signed : 'spike_signed'
# - Poisson input neurons : 'poisson'
# - Poisson input neurons signed : 'poisson_signed'
# - Integrate and fire input : 'if'
#
# The next image defines an integrate and fire neuron, this was obtained from Fast-Classifying, High-Accuracy Spiking Deep
# Networks Through Weight and Threshold paper by Diehl, etc al.
# ![image.png](attachment:image.png)
#
#
# ## Weight normalization methods
#
# In order to obtain near-lossless accuracy and faster convergence, a weight normalization method most be applied for the conversion of the ANN. This is because these techniques ensure that the activations of the networks are sufficiently small to prevent the ReLU from overestimating output activations. The x_norm parameter in each of the classes is the sample data that will be used for making the transformation.
#
# ### Data Normalization
#
# In this technique, some of the training set is used to estimate typical activations within the network. The training set is propagated through the network and the ReLU activations are stored. The weights are then normalized according to the maximum possible activation within the training set, so that this case only emits a single spike. This normalization also takes into account the maximum single input weight as well. The algorithm (taken from Fast-Classifying, High-Accuracy Spiking Deep
# Networks Through Weight and Threshold paper by Diehl, etc al.) can be seen next:
#
# ![image-2.png](attachment:image-2.png)
#
# - Data Normalization : DataNorm(norm_data=[norm_data], input_type=)
#
# ### Spike Normalization
#
# This weight normalization technique balances the threshold of each layer by considering the actual operation of the SNN in the loop during the ANN-SNN conversion process. To minimize the temporal delay of the neuron and ensure that the neuron firing threshold is not too low, here we weight-normalize the first layer depending on the maximum spike-based input received by the first layer. After the threshold of the first layer is set, a representative spike train at the output of the first layer is provided that enables the generation of the input spike-stream for the next layer. This is used to calculate the next threshold. This is all based on the article Going Deeper in Spiking Neural Networks: VGG and Residual Architectures by Sengupta, et al. A diagram that represent the pseudo code is now presented:
#
# ![image-3.png](attachment:image-3.png)
#
# - Spike Normalization  : SpikeNorm(norm_data=[norm_data], norm_time=norm_time, input_type=self.input_type)
#
# ### Few Spikes
#
# - FS : FewSpike(K=K, norm_data=[norm_data])
#
#
# ### Simple
#
# - Simple : Simple(input_type=)

# %%
converter_type = 'fs'
norm_time = 10 if (converter_type == 'fs') else 2500
if (converter_type == 'fs'):
    converter  = FewSpike(K=norm_time, norm_data=[x_norm])
elif (converter_type == 'dn'):
    converter = DataNorm(norm_data=[x_norm], input_type='poisson')
elif (converter_type == 'sn'):
    converter = SpikeNorm(norm_data=[x_norm], norm_time=norm_time, input_type='poisson')
elif not converter:
    converter = Simple(input_type='poisson')

# %% [markdown]
# Then, we create the ML model GeNN model based on the Tensorflow model. The function is called convert_tf_model. It has the following parameters:
#
# - tf_model : this is the tensorflow model that you wish to convert.
#
# - converter : the converter that we previously defined to trasform
#
# - connectivity_type : 'procedural' or 'sparse'
#
# - dt :
#
# - batch_size : the batch size for doing the Data Normalization
#
# - rng_seed : A seed
#
# - kernel_profiling : True
#
#
# Compile_kwargs -- additional arguments to pass trhough to the model.

# %%
# Convert and compile ML GeNN model
mlg_model = Model.convert_tf_model(
    vgg13_model, converter=converter, connectivity_type='procedural',
    dt=1.0, batch_size=1, rng_seed=0, 
    kernel_profiling=True)
# Out:
# converting Conv2D layer <conv2d>
# converting Conv2D layer <conv2d_1>
# deferring AveragePooling2D layer <average_pooling2d>
# converting AveragePooling2D -> Conv2D layers <conv2d_2>
# converting Conv2D layer <conv2d_3>
# deferring AveragePooling2D layer <average_pooling2d_1>
# converting AveragePooling2D -> Conv2D layers <conv2d_4>
# converting Conv2D layer <conv2d_5>
# deferring AveragePooling2D layer <average_pooling2d_2>
# converting AveragePooling2D -> Conv2D layers <conv2d_6>
# converting Conv2D layer <conv2d_7>
# deferring AveragePooling2D layer <average_pooling2d_3>
# converting AveragePooling2D -> Conv2D layers <conv2d_8>
# converting Conv2D layer <conv2d_9>
# ignoring Dropout layer <dropout>
# deferring AveragePooling2D layer <average_pooling2d_4>
# ignoring Flatten layer <flatten>
# converting AveragePooling2D -> Dense layers <dense>
# ignoring Dropout layer <dropout_1>
# converting Dense layer <dense_1>
# ignoring Dropout layer <dropout_2>
# converting Dense layer <dense_2>
# layer <conv2d> threshold: 2.113467216491699
# layer <conv2d_1> threshold: 3.6551496730112074
# layer <conv2d_2> threshold: 0.8083966865138973
# layer <conv2d_3> threshold: 4.150366937843527
# layer <conv2d_4> threshold: 1.1336644046103797
# layer <conv2d_5> threshold: 2.8635984690061904
# layer <conv2d_6> threshold: 1.144164697685443
# layer <conv2d_7> threshold: 1.5141886026938443
# layer <conv2d_8> threshold: 0.30485590745217345
# layer <conv2d_9> threshold: 0.26908544577887156
# layer <dense> threshold: 0.34870402350688995
# layer <dense_1> threshold: 2.8208581286215204
# layer <dense_2> threshold: 0.08501589361727313

# %% [markdown]
# Then, we evaluate the performance of the SNN model by trying it on the validation data.

# %%
time = 2500 #  --  sample presentation time (msec)
mlg_eval_start_time = perf_counter()
acc, spk_i, spk_t = mlg_model.evaluate([test_images], [test_labels], time, save_samples=[])
print("MLG evaluation:%f" % (perf_counter() - mlg_eval_start_time))
# Out:
# 100%|██████████| 10000/10000 [2:10:41<00:00,  1.28it/s, accuracy: 65.66]
# MLG evaluation:7841.515505

# %%
print('Accuracy of VGG16 GeNN model: {}%'.format(acc[0]))
# Out:
# Accuracy of VGG16 GeNN model: 65.66%

# %% [markdown]
# ## Few Spikes based transformation

# %%
converter = FewSpike(K=10, signed_input=True, norm_data=[x_norm])

# %%
# Convert and compile ML GeNN model
mlg_model = Model.convert_tf_model(
    vgg13_model, converter=converter, connectivity_type='procedural',
    dt=1.0, batch_size=1, rng_seed=0, 
    kernel_profiling=True)
# Out:
# converting Conv2D layer <conv2d>
# converting Conv2D layer <conv2d_1>
# deferring AveragePooling2D layer <average_pooling2d>
# converting AveragePooling2D -> Conv2D layers <conv2d_2>
# converting Conv2D layer <conv2d_3>
# deferring AveragePooling2D layer <average_pooling2d_1>
# converting AveragePooling2D -> Conv2D layers <conv2d_4>
# converting Conv2D layer <conv2d_5>
# deferring AveragePooling2D layer <average_pooling2d_2>
# converting AveragePooling2D -> Conv2D layers <conv2d_6>
# converting Conv2D layer <conv2d_7>
# deferring AveragePooling2D layer <average_pooling2d_3>
# converting AveragePooling2D -> Conv2D layers <conv2d_8>
# converting Conv2D layer <conv2d_9>
# ignoring Dropout layer <dropout>
# deferring AveragePooling2D layer <average_pooling2d_4>
# ignoring Flatten layer <flatten>
# converting AveragePooling2D -> Dense layers <dense>
# ignoring Dropout layer <dropout_1>
# converting Dense layer <dense_1>
# ignoring Dropout layer <dropout_2>
# converting Dense layer <dense_2>

# %%
time = 10 #  --  sample presentation time (msec)
mlg_eval_start_time = perf_counter()
acc, spk_i, spk_t = mlg_model.evaluate([test_images], [test_labels], time, save_samples=[])
print("MLG evaluation:%f" % (perf_counter() - mlg_eval_start_time))
# Out:
# 100%|██████████| 10000/10000 [01:32<00:00, 108.34it/s, accuracy: 98.71]
# MLG evaluation:92.307003

# %%
print('Accuracy of VGG16 GeNN model: {}%'.format(acc[0]))
# Out:
# Accuracy of VGG16 GeNN model: 98.71%
